# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import glob
import os
from scipy.stats import entropy
import pickle

# %%
paths = ["Football-Dataset/" + d for d in os.listdir("Football-Dataset/")]
files =[]
for path in paths:
    files = files + [path +"/"+ f for f in os.listdir(path) if f.endswith('.csv')]
matches = pd.concat(map(pd.read_csv, files))

# %%
matches.head()
# Out:
#           Home_Team            Away_Team Result  \
# 0       Saarbrücken  Stuttgarter Kickers    1-0
# 1       SC Freiburg         Unterhaching    2-3
# 2     VfL Osnabrück               Meppen    1-1
# 3          RW Essen           Schalke 04    0-0
# 4  Alemannia Aachen         MSV Duisburg    1-2
#
#                                                 Link Season Round  League
# 0  https://www.besoccer.com/match/saarbrucken/stu...   1990     1  2_liga
# 1  https://www.besoccer.com/match/sc-freiburg/unt...   1990     1  2_liga
# 2  https://www.besoccer.com/match/vfl-osnabruck/m...   1990     1  2_liga
# 3  https://www.besoccer.com/match/rot-weiss-essen...   1990     1  2_liga
# 4  https://www.besoccer.com/match/alemannia-aache...   1990     1  2_liga

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146498 entries, 0 to 327
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Home_Team  146498 non-null  object
#  1   Away_Team  146498 non-null  object
#  2   Result     146498 non-null  object
#  3   Link       146498 non-null  object
#  4   Season     146498 non-null  object
#  5   Round      146498 non-null  object
#  6   League     146498 non-null  object
# dtypes: object(7)
# memory usage: 8.9+ MB

# %%
#number of teams
nTeams = matches.groupby("League").Home_Team.nunique()
nTeams
# Out:
# League
# 2_liga              83
# bundesliga          46
# championship        63
# eerste_divisie      35
# eredivisie          32
# ligue_1             46
# ligue_2             75
# premier_league      52
# primeira_liga       43
# primera_division    51
# segunda_division    96
# segunda_liga        54
# serie_a             50
# serie_b             87
# Name: Home_Team, dtype: int64

# %%
def parseResult(result):
    try:
        values = result.split("-")
        first = int(values[0])
        second = int(values[1])
        if first > second:
            return "0"
        elif first < second:
            return "1"
        else:
            return "2"
    except:
        return ""
    pass

# %%
#Add a new feature to describe the outcome of a match.Home when Home_Team is the winner and Away when Away_Team is the winner
matches['OutCome'] = matches['Result'].apply(lambda x: parseResult(x))
matches = matches.query('OutCome != ""') 
matches
# Out:
#             Home_Team            Away_Team Result  \
# 0         Saarbrücken  Stuttgarter Kickers    1-0
# 1         SC Freiburg         Unterhaching    2-3
# 2       VfL Osnabrück               Meppen    1-1
# 3            RW Essen           Schalke 04    0-0
# 4    Alemannia Aachen         MSV Duisburg    1-2
# ..                ...                  ...    ...
# 323             Lecce                 SPAL    1-2
# 324         Frosinone           Cittadella    1-1
# 325           Reggina             Vicenza     3-0
# 326           Venezia        Nuova Cosenza    3-0
# 327            Chievo                 Pisa    2-0
#
#                                                   Link Season Round   League  \
# 0    https://www.besoccer.com/match/saarbrucken/stu...   1990     1   2_liga
# 1    https://www.besoccer.com/match/sc-freiburg/unt...   1990     1   2_liga
# 2    https://www.besoccer.com/match/vfl-osnabruck/m...   1990     1   2_liga
# 3    https://www.besoccer.com/match/rot-weiss-essen...   1990     1   2_liga
# 4    https://www.besoccer.com/match/alemannia-aache...   1990     1   2_liga
# ..                                                 ...    ...   ...      ...
# 323  https://www.besoccer.com/match/lecce/spal-1907...   2021    33  serie_b
# 324  https://www.besoccer.com/match/frosinone-calci...   2021    33  serie_b
# 325  https://www.besoccer.com/match/reggina/vicenza...   2021    33  serie_b
# 326  https://www.besoccer.com/match/venezia/nuova-c...   2021    33  serie_b
# 327  https://www.besoccer.com/match/chievo/pisa-cal...   2021    33  serie_b
#
#     OutCome
# 0         0
# 1         1
# 2         2
# 3         2
# 4         1
# ..      ...
# 323       1
# 324       2
# 325       0
# 326       0
# 327       0
#
# [146492 rows x 8 columns]

# %%
plt.hist(sorted(matches.OutCome),weights=np.ones(len(matches.OutCome)) / len(matches.OutCome))
# Out:
# (array([0.4614723 , 0.        , 0.        , 0.        , 0.        ,
#         0.25579554, 0.        , 0.        , 0.        , 0.28273216]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <a list of 10 Patch objects>)

# %%
#def normalizeEntropy(entropy,k):
 #   return entropy/np.log(k)

# %%
#normalizeEntropy(entropy(livMatches.groupby('outcome')["Result"].count()),3)

# %%
fig, axes = plt.subplots(5, 7, figsize=(30,30), dpi=100, sharex=True, sharey=True)
for i, (ax, Season) in enumerate(zip(axes.flatten(), matches.Season.unique())):
    x = matches.loc[matches.Season==Season, 'OutCome']
    ax.hist(x, alpha=0.5, bins=100, density=True, stacked=True,label=str(Season))
    ax.set_title(Season)
plt.suptitle('Result by Season', size=16)
# Out:
# Text(0.5, 0.98, 'Result by Season')

# %%
tm = pd.read_csv("DataToAdd/Match_Info.csv")

# %%
ti = pd.read_csv("DataToAdd/Team_Info.csv")

# %%
Elo = pickle.load(open('DataToAdd/elo_dict.pkl', 'rb'))

# %%
matches["ELO_Home"] = matches["Link"].apply(lambda x:Elo[x]["Elo_home"])
matches["ELO_Away"] = matches["Link"].apply(lambda x:Elo[x]["Elo_away"])

# %%
matches["Link"] = matches["Link"].apply(lambda x: x.replace("https://www.besoccer.com",""))
matches["Link"] = matches["Link"].apply(lambda x:x[0:len(x)-4])

# %%
matches["Link"].head()
# Out:
# 0    /match/saarbrucken/stuttgarter-kickers/1990
# 1           /match/sc-freiburg/unterhaching/1990
# 2               /match/vfl-osnabruck/meppen/1990
# 3         /match/rot-weiss-essen/schalke-04/1990
# 4      /match/alemannia-aachen/msv-duisburg/1990
# Name: Link, dtype: object

# %%
tm["Link"].head()
# Out:
# 0    /match/saarbrucken/stuttgarter-kickers/1990
# 1           /match/sc-freiburg/unterhaching/1990
# 2               /match/vfl-osnabruck/meppen/1990
# 3         /match/rot-weiss-essen/schalke-04/1990
# 4      /match/alemannia-aachen/msv-duisburg/1990
# Name: Link, dtype: object

# %%
ti.head()
# Out:
#               Team                 City  Country                    Stadium  \
# 0  Wattenscheid 09  Bochum-Wattenscheid  Germany           Lohrheidestadion
# 1       Hertha BSC               Berlín  Germany      Olympiastadion Berlin
# 2     Unterhaching         Unterhaching  Germany     Sportpark Unterhaching
# 3     Fortuna Köln              Cologne  Germany                 Südstadion
# 4     MSV Duisburg            Duisburgo  Germany  Schauinsland-Reisen-Arena
#
#   Capacity    Pitch
# 0    16233  Natural
# 1    76065  Natural
# 2    15053  Natural
# 3    14944  Natural
# 4    31514  Natural

# %%
matches = matches.merge(tm, how='left', on='Link')
ti=ti.rename(columns={"Team":"Home_Team"})
matches = matches.merge(ti, how='left', on='Home_Team')

# %%
matches.head()
# Out:
#           Home_Team            Away_Team Result  \
# 0       Saarbrücken  Stuttgarter Kickers    1-0
# 1       SC Freiburg         Unterhaching    2-3
# 2     VfL Osnabrück               Meppen    1-1
# 3          RW Essen           Schalke 04    0-0
# 4  Alemannia Aachen         MSV Duisburg    1-2
#
#                                           Link Season Round  League OutCome  \
# 0  /match/saarbrucken/stuttgarter-kickers/1990   1990     1  2_liga       0
# 1         /match/sc-freiburg/unterhaching/1990   1990     1  2_liga       1
# 2             /match/vfl-osnabruck/meppen/1990   1990     1  2_liga       2
# 3       /match/rot-weiss-essen/schalke-04/1990   1990     1  2_liga       2
# 4    /match/alemannia-aachen/msv-duisburg/1990   1990     1  2_liga       1
#
#    ELO_Home  ELO_Away  ...                               Referee Home_Yellow  \
# 0      56.0      59.0  ...    \r\nReferee: Hans-Jürgen Weber\r\n         0.0
# 1      53.0      55.0  ...          \r\nReferee: Kurt Wittke\r\n         1.0
# 2      52.0      53.0  ...       \r\nReferee: Werner Föckler\r\n         3.0
# 3      53.0      62.0  ...         \r\nReferee: Heinz Werner\r\n         2.0
# 4      57.0      52.0  ...  \r\nReferee: Hans-Peter Dellwing\r\n         1.0
#
#    Home_Red  Away_Yellow  Away_Red         City  Country              Stadium  \
# 0       0.0          3.0       0.0  Saarbrücken  Germany  Stadion Ludwigspark
# 1       0.0          0.0       0.0     Freiburg  Germany  Schwarzwald-Stadion
# 2       0.0          2.0       0.0    Osnabrück  Germany        osnatel-ARENA
# 3       0.0          2.0       0.0        Essen  Germany        Stadion Essen
# 4       0.0          1.0       0.0       Aachen  Germany         Neuer Tivoli
#
#   Capacity           Pitch
# 0    35286         Natural
# 1    24000         Natural
# 2    16130          Césped
# 3    20650         Natural
# 4    32960  cesped natural
#
# [5 rows x 21 columns]

# %%
nCol=len(matches.columns)
matches.insert(nCol, 'Goal_Scored', 0)

# %%
nCol=len(matches.columns)
matches.insert(nCol, 'Goal_Collected', 0)

# %%
currentSeason = matches.iloc[0]["Season"]
currentLeague = matches.iloc[0]["League"]
Scores = {}

# %%
class TeamScore:
  def __init__(self, goalScored, goalCollected):
    self.goalScored = goalScored
    self.goalCollected = goalCollected

# %%
def SetScore(HomeTeam,AwayTeam,GoalHome,GoalAway):
    if HomeTeam in Scores:
        scoreTeam = Scores[HomeTeam]
        scoreTeam.goalScored = scoreTeam.goalScored + GoalHome
        scoreTeam.goalCollected = scoreTeam.goalCollected + GoalAway
    else:
        teamScore = TeamScore(GoalHome,GoalAway)
        Scores[HomeTeam] = teamScore
        
    if AwayTeam in Scores:
        scoreTeam = Scores[AwayTeam]
        scoreTeam.goalScored = scoreTeam.goalScored + GoalAway
        scoreTeam.goalCollected = scoreTeam.goalCollected + GoalHome
    else:
        teamScore = TeamScore(GoalAway,GoalHome)
        Scores[AwayTeam] = teamScore

# %%
def UpdateScore(match):
    values = match.Result.split("-")
    first = int(values[0])
    second = int(values[1])
    if match["Home_Team"] in Scores.keys():
        match["Goal_Scored"] =  Scores[match["Home_Team"]].goalScored
        match["Goal_Collected"] =  Scores[match["Home_Team"]].goalCollected
    else:
        match["Goal_Scored"] = 0
        match["Goal_Collected"] = 0         
    SetScore(match["Home_Team"],match["Away_Team"],first,second)    
    return match

# %%
matches = matches.query('Season == 1990').apply(UpdateScore,axis=1)

# %%
matches.query('(Home_Team =="Saarbrücken" or Away_Team =="Saarbrücken") and Season == 1990').head(5)
# Out:
#        Home_Team            Away_Team Result  \
# 0    Saarbrücken  Stuttgarter Kickers    1-0
# 14  MSV Duisburg          Saarbrücken    1-1
# 20   Saarbrücken          Hannover 96    2-0
# 35    Schalke 04          Saarbrücken    1-2
# 46   Saarbrücken               Meppen    4-0
#
#                                            Link  Season  Round  League  \
# 0   /match/saarbrucken/stuttgarter-kickers/1990    1990      1  2_liga
# 14         /match/msv-duisburg/saarbrucken/1990    1990      2  2_liga
# 20          /match/saarbrucken/hannover-96/1990    1990      3  2_liga
# 35           /match/schalke-04/saarbrucken/1990    1990      4  2_liga
# 46               /match/saarbrucken/meppen/1990    1990      5  2_liga
#
#    OutCome  ELO_Home  ELO_Away  ... Home_Red Away_Yellow  Away_Red  \
# 0        0      56.0      59.0  ...      0.0         3.0       0.0
# 14       2      52.0      56.0  ...      0.0         3.0       0.0
# 20       0      56.0      60.0  ...      0.0         3.0       0.0
# 35       1      62.0      56.0  ...      0.0         1.0       0.0
# 46       0      57.0      53.0  ...      0.0         3.0       0.0
#
#              City  Country                    Stadium Capacity    Pitch  \
# 0     Saarbrücken  Germany        Stadion Ludwigspark    35286  Natural
# 14      Duisburgo  Germany  Schauinsland-Reisen-Arena    31514  Natural
# 20    Saarbrücken  Germany        Stadion Ludwigspark    35286  Natural
# 35  Gelsenkirchen  Germany              VELTINS-Arena    62271  Natural
# 46    Saarbrücken  Germany        Stadion Ludwigspark    35286  Natural
#
#    Goal_Scored Goal_Collected
# 0            1              0
# 14           2              1
# 20           3              1
# 35           5              5
# 46           7              2
#
# [5 rows x 23 columns]
